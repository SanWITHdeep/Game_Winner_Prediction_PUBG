# %% [markdown]
# # **`PRCP-1012-GameWinnerPred 🎮`**

# %% [markdown]
# ![game predictor1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Problem Statement Link - https://docs.google.com/document/d/1NKEOCCdB9-XxPq6fsyP5YSC2hiecbJqw/edit?usp=sharing&ouid=107018655340626469260&rtpof=true&sd=true

# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Insight:
# These are essential libraries for data manipulation (pandas, numpy), visualization (seaborn, matplotlib), and plotting graphs.

# %% [markdown]
# ### ***NOTE*** :
# ``` If you DONT want to import file from Drive, instead youre importing the file LOCALly  then replace the content stored in 'path' to 'YourDataFileName.csv'. ```
#
#
# ``` Comment-out the below code cell [Mounting Google Drive] ```

# %% [markdown]
# # Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Insight:
# This mounts Google Drive to access files stored there. This code is specific to Google Colab.

# %% [markdown]
# # Specifying File Path and Reading Data

# %%
path = '/content/drive/MyDrive/PTID-CDS-MAR-24-1870 : Internship Projects/PRCP-1012-GameWinnerPred/Data/pubg.csv'
data = pd.read_csv(path)

# %% [markdown]
# Insight:
# Specifies the path to the dataset stored in Google Drive and reads it into a DataFrame named data.

# %% [markdown]
# # Basic Checks

# %%
data.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               object
#  1   groupId          object
#  2   matchId          object
#  3   assists          int64
#  4   boosts           int64
#  5   damageDealt      float64
#  6   DBNOs            int64
#  7   headshotKills    int64
#  8   heals            int64
#  9   killPlace        int64
#  10  killPoints       int64
#  11  kills            int64
#  12  killStreaks      int64
#  13  longestKill      float64
#  14  matchDuration    int64
#  15  matchType        object
#  16  maxPlace         int64
#  17  numGroups        int64
#  18  rankPoints       int64
#  19  revives          int64
#  20  rideDistance     float64
#  21  roadKills        int64
#  22  swimDistance     float64
#  23  teamKills        int64
#  24  vehicleDestroys  int64
#  25  walkDistance     float64
# ...

# %%
data.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06   4.446966e+06
# mean   2.338149e-01  1.106908e+00  1.307171e+02  6.578755e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06  4.446966e+06
# mean   1.370147e+00  4.759935e+01  5.050060e+02  9.247833e-01  5.439551e-01
# ...

# %% [markdown]
# Insight:
#
# data.head() displays the first five rows of the dataset.
# data.info() provides a concise summary, including the number of entries, columns, and data types.
# data.describe() gives statistical summaries of numerical columns.

# %% [markdown]
# # Data Preprocessing

# %%
data = data.drop(columns=['Id', 'groupId', 'matchId'])
data = data.dropna()

# %% [markdown]
# Insight:
#
# Dropping columns that are not useful for prediction.
# Removing rows with missing values to ensure clean data.

# %% [markdown]
# # Display Basic Statistics

# %%
data.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  4.446965e+06  4.446965e+06  4.446965e+06  4.446965e+06   4.446965e+06
# mean   2.338150e-01  1.106908e+00  1.307172e+02  6.578757e-01   2.268196e-01
# std    5.885731e-01  1.715794e+00  1.707806e+02  1.145743e+00   6.021553e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.424000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.860000e+02  1.000000e+00   0.000000e+00
# max    2.200000e+01  3.300000e+01  6.616000e+03  5.300000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  4.446965e+06  4.446965e+06  4.446965e+06  4.446965e+06  4.446965e+06
# mean   1.370148e+00  4.759936e+01  5.050062e+02  9.247835e-01  5.439553e-01
# ...

# %% [markdown]
# Insight:
# Provides statistical summaries of the cleaned data.

# %% [markdown]
# # Shuffle and Trim Data

# %%
data = data.sample(frac=1).reset_index(drop=True)
data = data.iloc[:-4300000] #Huge data == Huge RAM space requried (So removing the data rows to reduce computation)

# %% [markdown]
# Insight:
#
# Shuffles the dataset randomly.
# Removes the last 4,300,000 rows, possibly to manage memory or focus on a subset.

# %% [markdown]
# ```
# # Suggestion : Dont Trim the Rows if your system has great computational power.
# ```
# ```
# # Large DataSet == More Precise Prediction / More Accurate
# ```

# %% [markdown]
# # Data Info Check Post-Processing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146965 entries, 0 to 146964
# Data columns (total 26 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   assists          146965 non-null  int64
#  1   boosts           146965 non-null  int64
#  2   damageDealt      146965 non-null  float64
#  3   DBNOs            146965 non-null  int64
#  4   headshotKills    146965 non-null  int64
#  5   heals            146965 non-null  int64
#  6   killPlace        146965 non-null  int64
#  7   killPoints       146965 non-null  int64
#  8   kills            146965 non-null  int64
#  9   killStreaks      146965 non-null  int64
#  10  longestKill      146965 non-null  float64
#  11  matchDuration    146965 non-null  int64
#  12  matchType        146965 non-null  object
#  13  maxPlace         146965 non-null  int64
#  14  numGroups        146965 non-null  int64
#  15  rankPoints       146965 non-null  int64
# ...

# %% [markdown]
# Insight:
# Rechecking the dataset to understand its structure after the previous transformations.

# %% [markdown]
# # One-Hot Encoding for Categorical Data

# %%
data = pd.get_dummies(data, columns=['matchType'])

# %% [markdown]
# Insight:
# Converts categorical matchType into numerical format using one-hot encoding.

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Correlation Matrix

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(data.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Insight:
# Plots the correlation matrix to understand relationships between variables.

# %% [markdown]
# ### Distribution of Target Variable

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['winPlacePerc'], bins=50, kde=True)
plt.title('Distribution of Win Place Percentage')
plt.xlabel('Win Place Percentage')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Insight:
# Shows the distribution of the target variable winPlacePerc.

# %% [markdown]
# ### Pairplot for Selected Features

# %%
selected_features = ['heals','kills', 'damageDealt', 'walkDistance', 'boosts', 'winPlacePerc']
sns.pairplot(data[selected_features])
plt.show()

# %% [markdown]
# Insight:
# Visualizes relationships between selected features and the target variable.

# %% [markdown]
# ## Insights from EDA

# %% [markdown]
# High correlation between 'kills', 'damageDealt', 'walkDistance', and 'winPlacePerc'.
# Players with higher 'kills' and 'damageDealt' tend to have higher win probabilities.
# 'walkDistance' is a significant factor in predicting win probability.

# %% [markdown]
# # Data Preprocessing for Modeling

# %% [markdown]
# ### Import Libraries for Model Training and Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Insight:
# Importing necessary libraries for model training and evaluation.

# %% [markdown]
# ### Splitting Data into Features and Target

# %%
X = data.drop(columns=['winPlacePerc'])
y = data['winPlacePerc']

# %% [markdown]
# Insight:
# Separating the features (X) and the target variable (y).

# %% [markdown]
# ### Standardize the Features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Insight:
# Standardizing features to have a mean of 0 and a standard deviation of 1.

# %% [markdown]
# ### Split Data into Training and Testing Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# Insight:
# Splitting the dataset into training (80%) and testing (20%) sets.

# %% [markdown]
# # Model Training and Evaluation

# %% [markdown]
# ### RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

mse = mean_squared_error(y_test, y_pred_rf)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_rf)

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.007909103445207566
# Root Mean Squared Error: 0.08893314030892852
# R-squared: 0.9161103213872004

# %% [markdown]
# Insight:
#
# Training a RandomForestRegressor model.
# Evaluating its performance using Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared metrics.

# %% [markdown]
# ### LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

mse1 = mean_squared_error(y_test, y_pred_lr)
rmse1 = np.sqrt(mse1)
r21 = r2_score(y_test, y_pred_lr)

print(f"Mean Squared Error: {mse1}")
print(f"Root Mean Squared Error: {rmse1}")
print(f"R-squared: {r21}")
# Out:
# Mean Squared Error: 0.015570047939794924
# Root Mean Squared Error: 0.12477999815593413
# R-squared: 0.8348527963119846

# %% [markdown]
# Insight:
#
# Training a Linear Regression model.
# Evaluating its performance using the same metrics as above.

# %% [markdown]
# ### DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

mse2 = mean_squared_error(y_test, y_pred_dt)
rmse2 = np.sqrt(mse2)
r22 = r2_score(y_test, y_pred_dt)

print(f"Mean Squared Error: {mse2}")
print(f"Root Mean Squared Error: {rmse2}")
print(f"R-squared: {r22}")
# Out:
# Mean Squared Error: 0.016529683048685063
# Root Mean Squared Error: 0.12856781497981937
# R-squared: 0.824674211415724

# %% [markdown]
# Insight:
#
# Training a Decision Tree Regressor model.
# Evaluating its performance using the same metrics.

# %% [markdown]
# # Metrics Comparision
#
# ```
# > Random Forest Regressor
#
# 1.   MSE    : 0.007
# 2.   RMSE   : 0.088
# 3.   R2     : 0.916 == 91.6% Accurate ✅
#
# > Linear Regressor
#
# 1.   MSE    : 0.015
# 2.   RMSE   : 0.124
# 3.   R2     : 0.834 == 83.4% Accurate
#
# > Decision Tree Regressor
#
# 1.   MSE    : 0.015
# 2.   RMSE   : 0.128
# 3.   R2     : 0.824 == 82.4% Accurate
#
# ```
#
# ---
# ```Note : Higher the R2 Score & Lesser the MSE and RMSE == More Accurate the Prediction```

# %% [markdown]
# # Overall Conclusion

# %% [markdown]
# The RandomForestRegressor model shows a good fit with the data, as indicated by the R-squared value. The other models (Linear Regression and Decision Tree Regressor) provide additional insights but may not perform as well as the RandomForestRegressor. This comprehensive analysis helps in predicting the winPlacePerc based on various features in the dataset, with kills, damageDealt, and walkDistance being significant predictors.

# %% [markdown]
# # Summary

# %% [markdown]
# The analysis involves reading and preprocessing the data, conducting exploratory data analysis to understand relationships and distributions, and training three different regression models (RandomForestRegressor, LinearRegression, DecisionTreeRegressor) to predict the win percentage. The RandomForestRegressor model appears to be the most effective based on evaluation metrics, suggesting it captures the complexities of the data better than the other models.

# %% [markdown]
# # Challenges Faced
# Certainly! Here's the list of challenges faced in standard form:
#
# 1. The dataset was large, making data cleaning a significant task.
# 2. Loading the 600MB dataset took more time.
# 3. The laptop crashed while training the data using Random Forest and Decision Tree models. The CPU usage was very high, exceeding 12GB of RAM in Google Colab's compute machine, leading to frequent crashes.
# 4. Reduced the number of rows in the dataset to improve execution speed.
# 5. The dataset had too many columns, making it difficult to find correlated data.
# 6. Plots took a long time to render.

# %% [markdown]
# # PTID-CDS-MAR-24-1870 Team Info:
# 1. Dipanjali
#
#          (01-MAY-23-CDS-ONL-BUN-021-WDE20)
#           email:satyas.behera@gmail.com / dipanjalipatra@gmail.com
#
# 2. Vinay C
#
#           (09-Oct-23-CDS-BUN-021-WDE20-ONL)
#           email: vinayvinay9617@gmail.com
#
# 3. Sandeep Chandra Sagar R
#
#           (09-Oct-23-CDS-BUN-021-WDE20-ONL)
#           email: sanwithdeep@gmail.com
